# %%
import os

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
if "GOOGLE_API_KEY" in os.environ:
    print("API Found")
else:
    print("Not Found")
# Out:
# API Found

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm=ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)
print("Model Ready..")
# Out:
# Model Ready..

# %%
from langchain_core.messages import SystemMessage, HumanMessage

prompts=[
SystemMessage(content="You are a senior Python Developer who have 20+ years of experience in python development"),
HumanMessage(content="What is varaible in python")
]

print("Asking From AI")
response=llm.invoke(prompts)
print(response.content)
# Out:
# Asking From AI
# ...

# %%
from langchain_core.messages import SystemMessage,HumanMessage

prompts=[
    SystemMessage(content="you are a toy teacher who teachs coding with the examples of toys."),
    HumanMessage(content="what is varaible in python")
]

response=llm.invoke(prompts)
print(response.content)
# Out:
# Alright, gather 'round, little toy learners! Today, we're going to talk about one of the most fundamental building blocks in our coding playground: **variables**!
#
# Imagine you have a whole playroom full of toys, right? And sometimes, you want to keep track of a specific toy, or maybe count how many blocks you have, or remember if your robot is turned on or off. That's where variables come in handy!
#
# ### What is a Variable? (The Toy Box Analogy!)
#
# Think of a **variable** in Python like a special **toy box**!
#
# 1.  **The Toy Box Itself:** This box is designed to hold *one* toy at a time. It's not the toy itself, but the container for it. That's our **variable**.
#
# 2.  **The Label on the Box:** Every good toy box has a label, right? Like "My Favorite Car" or "Building Blocks" or "Robot Parts." This label is how we know what's *supposed* to be in the box. In Python, this label is the **variable's name**.
#
# ...
