# %%
import os

from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
if "GOOGLE_API_KEY" in os.environ:
    print("API key sucessfully loaded")
else:
    print("API is not loaded properly")
# Out:
# API key sucessfully loaded

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)

print("Gemini Model is initialize and ready in memory")
# Out:
# Gemini Model is initialize and ready in memory

# %%
prompt="who is the prime minister of Pakistan ?"
print("waiting ......")
response= llm.invoke(prompt)
print("\n AI Response: ")
print(response.content)
# Out:
# waiting ......
#
#  AI Response:
# The current Prime Minister of Pakistan is **Shehbaz Sharif**.
#
# He took office for his second term on March 4, 2024, after the general elections held in February 2024. He is the leader of the Pakistan Muslim League (N) party.
